# %% [markdown]
# ## Temperature

# %%
# Setup
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# Loads variables from the environment
from os import getenv
from dotenv import load_dotenv
load_dotenv()
open_api_key = getenv("ANTHROPIC_API_KEY")

# %%
# Helper Functions
def add_user_message(messages, text):
    user_message = {
        "role": "user",
        "content": text
    }
    messages.append(user_message)
    
def add_assistant_message(messages, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    messages.append(assistant_message)

def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

add_user_message(
    messages,
    "Generate a one sentence movie idea."
)

answer = chat(messages, temperature=1.0)

answer
# Out:
# 'A lonely lighthouse keeper discovers that the ships he guides to safety each night exist only in the past, and he must choose between saving them and returning to his own time.'
