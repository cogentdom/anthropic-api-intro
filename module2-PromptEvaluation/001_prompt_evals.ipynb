# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and the test case input, then returns the result"""
    prompt=f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    # TODO - Grading
    score = 10

    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and call run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

run_eval(dataset)
# Out:
# [{'output': '# AWS Account ID Extractor from ARN\n\nHere\'s a comprehensive solution:\n\n```python\ndef extract_account_id_from_arn(arn: str) -> str | None:\n    """\n    Extract the AWS account ID from an ARN string.\n    \n    ARN format: arn:partition:service:region:account-id:resource-type/resource-id\n    \n    Args:\n        arn: The ARN string to parse\n        \n    Returns:\n        The 12-digit account ID if present, None otherwise\n        \n    Raises:\n        ValueError: If the ARN format is invalid\n    """\n    if not isinstance(arn, str):\n        raise ValueError("ARN must be a string")\n    \n    if not arn.startswith("arn:"):\n        raise ValueError("Invalid ARN: must start with \'arn:\'")\n    \n    # Split the ARN by colons\n    parts = arn.split(":")\n    \n    # ARN format: arn:partition:service:region:account-id:resource...\n    # Minimum valid ARN has 6 parts (arn, partition, service, region, account-id, resource)\n    if len(parts) < 6:\n        return None\n    \n    account_id = parts[4]\n    \n    # Account ID should be either empty string (for services like S3) or 12 digits\n    if account_id == "":\n        return None\n    \n    if not account_id.isdigit() or len(account_id) != 12:\n        raise ValueError(f"Invalid account ID format: {account_id}")\n    \n    return account_id\n\n\n# Test cases\nif __name__ == "__main__":\n    # Test case 1: S3 bucket (no account ID)\n    arn1 = "arn:aws:s3:::my-bucket"\n    result1 = extract_account_id_from_arn(arn1)\n    print(f"S3 bucket ARN: {arn1}")\n    print(f"Account ID: {result1}\\n")\n    \n    # Test case 2: EC2 instance (with account ID)\n    arn2 = "arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0"\n    result2 = extract_account_id_from_arn(arn2)\n    print(f"EC2 instance ARN: {arn2}")\n    print(f"Account ID: {result2}\\n")\n    \n    # Test case 3: IAM role\n    arn3 = "arn:aws:iam::123456789012:role/MyRole"\n    result3 = extract_account_id_from_arn(arn3)\n    print(f"IAM role ARN: {arn3}")\n    print(f"Account ID: {result3}\\n")\n    \n    # Test case 4: Lambda function\n    arn4 = "arn:aws:lambda:us-west-2:123456789012:function:my-function"\n    result4 = extract_account_id_from_arn(arn4)\n    print(f"Lambda function ARN: {arn4}")\n    print(f"Account ID: {result4}\\n")\n    \n    # Test case 5: DynamoDB table\n    arn5 = "arn:aws:dynamodb:eu-west-1:123456789012:table/MyTable"\n    result5 = extract_account_id_from_arn(arn5)\n    print(f"DynamoDB table ARN: {arn5}")\n    print(f"Account ID: {result5}\\n")\n    \n    # Test case 6: Invalid ARN (missing account ID)\n    try:\n        arn6 = "arn:aws:ec2:us-east-1"\n        result6 = extract_account_id_from_arn(arn6)\n        print(f"Incomplete ARN: {arn6}")\n        print(f"Account ID: {result6}\\n")\n    except ValueError as e:',
#   'test_case': {'task': "Write a Python function that extracts the AWS account ID from an ARN string. The function should take an ARN like 'arn:aws:s3:::my-bucket' or 'arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0' and return the account ID if present, or None if not applicable."},
#   'score': 10},
#  {'output': '# AWS IAM Policy Statement for S3 Access with IP Restriction\n\n```json\n{\n  "Version": "2012-10-17",\n  "Statement": [\n    {\n      "Sid": "AllowS3ObjectAccessFromSpecificIP",\n      "Effect": "Allow",\n      "Principal": "*",\n      "Action": [\n        "s3:GetObject",\n        "s3:PutObject"\n      ],\n      "Resource": "arn:aws:s3:::your-bucket-name/*",\n      "Condition": {\n        "IpAddress": {\n          "aws:SourceIp": "10.0.0.0/8"\n        }\n      }\n    }\n  ]\n}\n```\n\n## Key Components Explained:\n\n| Element | Description |\n|---------|-------------|\n| **Version** | Policy language version (standard: "2012-10-17") |\n| **Sid** | Statement ID (optional but recommended for clarity) |\n| **Effect** | "Allow" grants permission; "Deny" would restrict access |\n| **Principal** | "*" allows any principal; use specific ARNs to restrict (e.g., "arn:aws:iam::123456789012:user/username") |\n| **Action** | S3 actions: s3:GetObject (read) and s3:PutObject (write) |\n| **Resource** | Bucket ARN with /* to include all objects; replace "your-bucket-name" with actual bucket name |\n| **Condition** | Restricts access to the specified IP range (10.0.0.0/8 = 10.0.0.0 - 10.255.255.255) |\n\n## Alternative: Specific Principal Example\n\n```json\n{\n  "Version": "2012-10-17",\n  "Statement": [\n    {\n      "Sid": "AllowS3ObjectAccessFromSpecificIP",\n      "Effect": "Allow",\n      "Principal": {\n        "AWS": "arn:aws:iam::123456789012:role/MyRole"\n      },\n      "Action": [\n        "s3:GetObject",\n        "s3:PutObject"\n      ],\n      "Resource": "arn:aws:s3:::your-bucket-name/*",\n      "Condition": {\n        "IpAddress": {\n          "aws:SourceIp": "10.0.0.0/8"\n        }\n      }\n    }\n  ]\n}\n```\n\n**Note:** Replace `your-bucket-name` and `123456789012` with actual values for your AWS environment.',
#   'test_case': {'task': 'Create a JSON object that represents an AWS IAM policy statement allowing a principal to perform s3:GetObject and s3:PutObject actions on a specific S3 bucket ARN with conditions restricting access to requests from a specific IP address range (10.0.0.0/8).'},
#   'score': 10},
#  {'output': "# AWS S3 Bucket Name Regular Expression\n\nHere's a comprehensive solution:\n\n```regex\n^(?!.*--)(?!-)(?!.*-$)[a-z0-9][a-z0-9-]{1,61}[a-z0-9]$|^[a-z0-9]{3}$\n```\n\n## Explanation\n\nLet me break down the regex into its components:\n\n```regex\n^(?!.*--)        # Negative lookahead: no consecutive hyphens anywhere\n(?!-)            # Negative lookahead: doesn't start with hyphen\n(?!.*-$)         # Negative lookahead: doesn't end with hyphen\n[a-z0-9]         # First character: lowercase letter or number\n[a-z0-9-]{1,61}  # Middle characters: 1-61 chars (lowercase, numbers, hyphens)\n[a-z0-9]         # Last character: lowercase letter or number\n$                # End of string\n|                # OR\n^[a-z0-9]{3}$    # Special case: exactly 3 characters (all lowercase/numbers)\n```\n\n## Why This Works\n\n1. **Length requirement (3-63)**: \n   - Main pattern: 1 + 61 + 1 = 63 chars max\n   - 3-char buckets: handled by the `|^[a-z0-9]{3}$` alternative\n\n2. **Start/End rules**: \n   - First char: `[a-z0-9]`\n   - Last char: `[a-z0-9]`\n   - Cannot start/end with hyphen (lookaheads prevent this)\n\n3. **Character restrictions**: Only `[a-z0-9-]` allowed\n\n4. **No consecutive hyphens**: `(?!.*--)` negative lookahead catches this\n\n## Examples\n\n```javascript\nconst s3BucketRegex = /^(?!.*--)(?!-)(?!.*-$)[a-z0-9][a-z0-9-]{1,61}[a-z0-9]$|^[a-z0-9]{3}$/;\n\n// Valid\ns3BucketRegex.test('my-bucket');              // true\ns3BucketRegex.test('my-bucket-123');          // true\ns3BucketRegex.test('abc');                    // true\ns3BucketRegex.test('a1b2c3');                 // true\n\n// Invalid\ns3BucketRegex.test('my--bucket');             // false (consecutive hyphens)\ns3BucketRegex.test('-my-bucket');             // false (starts with hyphen)\ns3BucketRegex.test('my-bucket-');             // false (ends with hyphen)\ns3BucketRegex.test('MyBucket');               // false (uppercase)\ns3BucketRegex.test('my_bucket');              // false (underscore not allowed)\ns3BucketRegex.test('ab');                     // false (too short)\n```\n\nThis regex fully complies with [AWS S3 bucket naming rules](https://docs.aws.amazon.com/AmazonS3/latest/userguide/bucketnamingrules.html).",
#   'test_case': {'task': 'Write a regular expression that matches valid AWS S3 bucket names according to AWS naming rules: 3-63 characters long, starting and ending with lowercase letters or numbers, containing only lowercase letters, numbers, and hyphens (no consecutive hyphens).'},
#   'score': 10}]
